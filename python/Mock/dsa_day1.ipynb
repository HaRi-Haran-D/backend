# %%
def square(num):
    sq_num=[]
    for i in num:
        sq_num.append(i*i)#+=[i*i]
    return sq_num

num=[2,5,8,9]
print(square(num))
# Out:
# [4, 25, 64, 81]

# %%
# binary search
# 0(n)
list = [4,9,15,21,34,57,68,91]
for i in list:#range(len(list)):
    if i == 68:
        print(i)

#
# Out:
# 68
