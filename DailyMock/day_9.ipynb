# %%
# 3. Write a program to remove duplicate elements from a list while maintaining order.
n = [3,2,3,1,4,1,2,5,6,3,1]
s = []
for i in n:
    if i not in s:
        s+=[i]

print(s)
# Out:
# [3, 2, 1, 4, 5, 6]

# %%
# 4. Write a Python program to reverse each word in a sentence.
import re
from collections import Counter

string = "Hello world, this is Python"

word = re.findall(r'\b\w+\b', string.lower())
print(word)
# Out:
# ['hello', 'world', 'this', 'is', 'python']

# %%
# 5. Write a program to find all prime numbers between 1 and N.

# start = 25
# end = 50
# print("Prime numbers between", start, "and", end, "are:")
#
# for num in range(2, end + 1):
#     if num > 1:
#         for i in range(2, num):
#             if (num % i) == 0:
#                 break
#         else:
#             print(num)
#
#
# for i in range(2,25):
#     if i > 1:
#         for j in range(2,i):
#             if i % j == 0:
#                 break
#         else:
#             print(i)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
# 23

# %%
# n = 5
#
# for i in range(n):
#     for j in range(n):
#         if i == j or i + j == n - 1:
#             print(i + 1, end=" ")
#         else:
#             print(" ", end=" ")
#     print()

n = 9

for i in range(n):
    num = i + 1 if i <= n // 2 else n - i
    for j in range(n):
        if i == j or i + j == n - 1:
            print(num, end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# 1               1
#   2           2
#     3       3
#       4   4
#         5
#       4   4
#     3       3
#   2           2
# 1               1

# %%
arr = [[1,1],[1,8],[2,2],[2,7],[3,3],[3,6],[4,4],[4,5],[5,4],[6,4],[6,5],[7,3],[7,6],[8,2],[8,7],[9,1],[9,8]]
a=0
for i in range(1,9):
    a+=1
    for j in range(1,9):
        if [i,j] in arr:
            print(a, end="")
        else:
            print(' ', end="")
    print()
# Out:
# 1      1
#  2    2
#   3  3
#    44
#    5
#    66
#   7  7
#  8    8

# %%
# def sum(n):
#     a=0
#     for i in range(1,n+1):
#         a+=i
#     return f'Sum is: {a}'
# print(sum(10))


# def table(n):
#     for i in range(1,11):
#         print(i*n)
# table(5)


# n=75869
# count=0
# while n !=0:
#     n = n // 10
#     count += 1
# print(count)


# for i in range(0,5):
#     for j in range(5-i,0,-1):
#         print(j, end=" ")
#     print()

list = [10,20,30,40,50]
for i in range(len(list)-1,-1,-1):
    print(list[i])
# Out:
# 50
# 40
# 30
# 20
# 10
