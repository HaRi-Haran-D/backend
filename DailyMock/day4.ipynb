# %%
# 1. Find the 2nd largest element without sorting or using built-in max().
list = [3,5,1,6,9,0]
emt=[]
for i in range(len(list)):
    for j in range(i+1,len(list)):
        if list[i] < list[j]:
            list[i],list[j] = list[j],list[i]
print(list[1])

first=list[0]

for i in list:
    if i > first:
        second = first
        first = i

print(second)
# Out:
# 6
# 6

# %%
# 2. Find the missing number in a list of 1 to n.
n=[1,2,4,5,6,8,9,12]
nn=[]
for i in range(0,len(n)):
    if n[i+1] - n[i] == 1:
        nn+=[n[i]]
    else:
        nn+=[n[i]+1]
print(nn)
# Out:
# KeyboardInterrupt

# %%
# 4. Reverse a list in-place without using [::-1] or reverse().
n=[1,2,4,5,6,8,9,12]
nn=[]
for i in range(len(n),0,-1):
    nn+=[n[i-1]]

print(nn)
# Out:
# [12, 9, 8, 6, 5, 4, 2, 1]

# %%
# 5. Find the first non-repeating element in a list.
list = [1,2,3,1,2,4,6,4]
n=[]
for i in list:
    if i not in n:
        n+=[i]
print(n)
# Out:
# [1, 2, 3, 4, 6]
