# %%
# 1. Find the second largest element in an array without sorting.
list = [5,8,9,10,12,40,50,23]
for i in range(len(list)):
    for j in range(len(list)):
        if list[i]>list[j]:
            list[i],list[j] = list[j],list[i]
print(list[1])
# Out:
# 40

# %%
# pyramid

for i in range(4,-1,-1):
    print(' '*i,end='')
    for j in range(4,i-1,-1):
        print('* ',end='')
    print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n=9
for i in range(n):
    if i <= n // 2:
        num = i + 1
    else:
        num = n - i
    for j in range(n):
        if i==j or i+j == n-1:
            print(num, end="")
        else:
            print(' ', end='')
    print()
# Out:
# 1       1
#  2     2
#   3   3
#    4 4
#     5
#    4 4
#   3   3
#  2     2
# 1       1

# %%
s='aaabbaaccc'
count={}
for i in s:
    if i in count:
        count[i]+=1
    else:
        count[i]=1
print(count)
# for i,j in count.items():
#     print(i,'=',j)
# Out:
# {'a': 5, 'b': 2, 'c': 3}

# %%
# 2. Move all zeros to the end of the array in-place.
list = [2,3,4,0,1,0,23,0,0,24,56]
zero=[]
no=[]
for i in list:
    if i == 0:
        zero+=[i]
    else:
        no+=[i]
list=no+zero
print(list)
# Out:
# [2, 3, 4, 1, 23, 24, 56, 0, 0, 0, 0]

# %%
s = [2, 3, 4, 1, 23, 24, 56, 0, 0, 0, 0]
f=[]
for i in range(len(s)-1,-1,-1):
    f+=[s[i]]
print(f)
# Out:
# [0, 0, 0, 0, 56, 24, 23, 1, 4, 3, 2]

# %%
# 3. Check if two strings are anagrams.
str1 = 'listen'
str2 = 'SILENT'

def anagram(str1,str2):
    s1=sorted(str1.lower().replace(' ',''))
    s2=sorted(str2.lower().replace(' ',''))
    return s1==s2
result=anagram(str1,str2)
print(f'Is "{str1}" an anagram of "{str2}"? {result}')
# Out:
# Is "listen" an anagram of "SILENT"? True

# %%
def rotate(arr, k):
    n = len(arr)
    k = k % n

    def reverse(start, end):
        while start < end:
            arr[start], arr[end] = arr[end], arr[start]
            start += 1
            end -= 1
    # Step 1: Reverse whole array
    reverse(0, n - 1)
    # Step 2: Reverse first k elements
    reverse(0, k - 1)
    # Step 3: Reverse remaining elements
    reverse(k, n - 1)
    return arr

arr = [1,2,3,4,5]
print(rotate(arr, 2))
# Out:
# [4, 5, 1, 2, 3]

# %%
arr = [1,2,3,4,5]
def rotate(arr,k):
    n=[]
    b=[]

    for i in range(len(arr)):
        if i <= k:
            n+=[arr[i]]
        else:
            b+=[arr[i]]
    arr = b + n
    return arr
print(rotate(arr,2))
# Out:
# [4, 5, 1, 2, 3]

# %%
#     1
#    232
#   34543
#  4567654
# 567898765

for i in range(5,0,-1):
    a=1
    print(' '*i, end='')
    for j in range(i-1,5):
        print(a,end='')
        a+=1
    print()
# Out:
#      1
#     12
#    123
#   1234
#  12345
