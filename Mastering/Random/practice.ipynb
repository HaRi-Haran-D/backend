# %%
import random

for i in range(0,10):
    n = random.randint(1,3)
    print(n)
# Out:
# 1
# 2
# 2
# 1
# 3
# 3
# 2
# 1
# 1
# 3

# %%
"""
Log File Analysis

Scenario:
You have a large server log file. Each line contains a timestamp, log level, and message. You need to find how many ERROR messages occurred in the last 24 hours.

Question:
Write a Python script to parse the file and count the ERROR logs.

Concepts Tested
File handling
String parsing
Date/time processing
"""

# %%
"""
Error Handling

Scenario:
Your Python program reads multiple files in a folder, but some files may be corrupted.

Question:
How do you ensure the program continues processing other files even if one fails?

Concepts Tested

try / except

logging

robust code design
"""

# %%
"""
Caching Problem

Scenario:
A function calculates expensive results and is called repeatedly with the same inputs.

Question:
How would you optimize it?

Concepts Tested

functools.lru_cache

memoization
"""
